# %%
# !git clone https://github.com/razarcon3/PyDreamerV1-DRL
# Out:
# Cloning into 'PyDreamerV1-DRL'...
# remote: Enumerating objects: 489, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 489 (delta 21), reused 26 (delta 16), pack-reused 446 (from 1)
# Receiving objects: 100% (489/489), 33.66 MiB | 48.27 MiB/s, done.
# Resolving deltas: 100% (231/231), done.

# %%
# %cd PyDreamerV1-DRL
# Out:
# /content/PyDreamerV1-DRL

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# !pip install addict
# Out:
# ...
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# ...

# %%
# !pip install dm-control
# Out:
# ...
#   Using cached dm_control-1.0.34-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached dm_env-1.6-py3-none-any.whl.metadata (966 bytes)
# ...
#   Using cached glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# ...
#   Using cached labmaze-1.0.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (274 bytes)
# ...
#   Using cached mujoco-3.3.7-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (41 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 MB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 109.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 23.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 127.4 MB/s eta 0:00:00
# ...

# %%
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#
#
# Aborted!
# ^C

# %%
# !python main.py --config dm_control/Cart-pole.yml
